# %% [markdown]
# # **DATA EXPLORATION**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Working_dir_path ='/content/drive/MyDrive/Copy of Indian-Resturants.csv'
df =pd.read_csv(Working_dir_path)

# %%
df
# Out:
#           res_id                            name      establishment  \
# 0        3400299                     Bikanervala      [Quick Bites]
# 1        3400005  Mama Chicken Mama Franky House      [Quick Bites]
# 2        3401013                   Bhagat Halwai      [Quick Bites]
# 3        3400290                   Bhagat Halwai      [Quick Bites]
# 4        3401744     The Salt Cafe Kitchen & Bar    [Casual Dining]
# ...          ...                             ...                ...
# 211882  19142822           Shree Janta Ice Cream  [Dessert Parlour]
# 211925  18984164                The Grand Thakar    [Casual Dining]
# 211926  18019952                     Geeta lodge    [Casual Dining]
# 211940   3200996                      Raju Omlet      [Quick Bites]
# 211942   3201138                          Subway      [Quick Bites]
#
#                                                   address      city  city_id  \
# ...

# %%
pd.set_option=('display.max_columns',None)

# %%
df
# Out:
#           res_id                            name      establishment  \
# 0        3400299                     Bikanervala    ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                   Bhagat Halwai    ['Quick Bites']
# 3        3400290                   Bhagat Halwai    ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
# ...          ...                             ...                ...
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# 0       https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %% [markdown]
# # **DATA** **CLEANING**
#
# 1. Remove unnecessary columns
#
# 2. Handle missing values
#
# 3. Fix data types
#
# 4. Remove duplicates
#
# 5. Convert string lists to actual lists
#
# # ** Convert Numeric Columns Properly**
#
#
# Some numeric values might be stored as strings. We need to convert them to integers or floats.
#
# aggregate_rating → Should be float
#
# opentable_support → Should be float
#
# price_range → Should be integer
#
# votes → Should be integer

# %%
 #Get the list of existing columns in the DataFrame
existing_columns = df.columns.tolist()

# Columns to drop
columns_to_drop = ['zipcode', 'url', 'country_id']

# Find the common columns between existing columns and columns to drop
valid_columns_to_drop = list(set(existing_columns) & set(columns_to_drop))

# Drop only the valid columns if they exist
if valid_columns_to_drop:
    df.drop(columns=valid_columns_to_drop, inplace=True)
else:
    print("None of the specified columns were found in the DataFrame.")
# Out:
# None of the specified columns were found in the DataFrame.

# %%
df.columns
# Out:
# Index(['res_id', 'name', 'establishment', 'address', 'city', 'city_id',
#        'locality', 'latitude', 'longitude', 'locality_verbose', 'cuisines',
#        'timings', 'average_cost_for_two', 'price_range', 'currency',
#        'highlights', 'aggregate_rating', 'rating_text', 'votes', 'photo_count',
#        'opentable_support', 'delivery', 'takeaway'],
#       dtype='object')

# %%
df['cuisines'].fillna("Unknown", inplace=True)
df['timings'].fillna("Unknown", inplace=True)
df['address'].fillna("Not Available", inplace=True)
df['opentable_support'].fillna(0, inplace=True)
# Out:
# <ipython-input-10-5758dba59169>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cuisines'].fillna("Unknown", inplace=True)
# <ipython-input-10-5758dba59169>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.describe()
# Out:
#              res_id       city_id      latitude     longitude  \
# count  5.556800e+04  55568.000000  55568.000000  55568.000000
# mean   1.313694e+07   3409.499298     21.450847     76.497131
# std    8.105959e+06   5174.942737     42.901135     10.982976
# min    5.000000e+01      1.000000      0.000000      0.000000
# 25%    3.001352e+06      8.000000     16.518374     74.645885
# 50%    1.869268e+07     26.000000     22.468629     77.106348
# 75%    1.887262e+07  11294.000000     26.752959     79.831641
# max    1.915979e+07  11354.000000  10000.000000     91.832769
#
#        average_cost_for_two   price_range  aggregate_rating         votes  \
# count          55568.000000  55568.000000      55568.000000  55568.000000
# mean             528.205874      1.714728          2.958593    223.330352
# std              595.028447      0.878227          1.464576    618.224019
# min                0.000000      1.000000          0.000000    -18.000000
# ...

# %%
df['aggregate_rating'] = df['aggregate_rating'].astype(float)
df['opentable_support'] = df['opentable_support'].astype(float)
df['price_range'] = df['price_range'].astype(int)
df['votes'] = df['votes'].astype(int)
df
# Out:
#           res_id                            name      establishment  \
# 0        3400299                     Bikanervala      [Quick Bites]
# 1        3400005  Mama Chicken Mama Franky House      [Quick Bites]
# 2        3401013                   Bhagat Halwai      [Quick Bites]
# 3        3400290                   Bhagat Halwai      [Quick Bites]
# 4        3401744     The Salt Cafe Kitchen & Bar    [Casual Dining]
# ...          ...                             ...                ...
# 211882  19142822           Shree Janta Ice Cream  [Dessert Parlour]
# 211925  18984164                The Grand Thakar    [Casual Dining]
# 211926  18019952                     Geeta lodge    [Casual Dining]
# 211940   3200996                      Raju Omlet      [Quick Bites]
# 211942   3201138                          Subway      [Quick Bites]
#
#                                                   address      city  city_id  \
# ...

# %%
df.drop_duplicates(subset='res_id', keep='first', inplace=True)
df
# Out:
#           res_id                            name        establishment  \
# 0        3400299                     Bikanervala      ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House      ['Quick Bites']
# 2        3401013                   Bhagat Halwai      ['Quick Bites']
# 3        3400290                   Bhagat Halwai      ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar    ['Casual Dining']
# ...          ...                             ...                  ...
# 211882  19142822           Shree Janta Ice Cream  ['Dessert Parlour']
# 211925  18984164                The Grand Thakar    ['Casual Dining']
# 211926  18019952                     Geeta lodge    ['Casual Dining']
# 211940   3200996                      Raju Omlet      ['Quick Bites']
# 211942   3201138                          Subway      ['Quick Bites']
#
#                                                   address      city  city_id  \
# ...

# %%
df.shape
# Out:
# (55568, 23)

# %%
import ast # import the ast module
def convert_to_list(value):
    try:
        return ast.literal_eval(value)  # Safely convert string to list
    except (ValueError, SyntaxError):
        return []

df['establishment'] = df['establishment'].apply(convert_to_list)
df['highlights'] = df['highlights'].apply(convert_to_list)

# Save cleaned dataset (optional)
df.to_csv("Cleaned_Indian_Restaurants.csv", index=False)

# Display dataset info
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55568 entries, 0 to 211942
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   res_id                55568 non-null  int64
#  1   name                  55568 non-null  object
#  2   establishment         55568 non-null  object
#  3   address               55568 non-null  object
#  4   city                  55568 non-null  object
#  5   city_id               55568 non-null  int64
#  6   locality              55568 non-null  object
#  7   latitude              55568 non-null  float64
#  8   longitude             55568 non-null  float64
#  9   locality_verbose      55568 non-null  object
#  10  cuisines              55568 non-null  object
#  11  timings               55568 non-null  object
#  12  average_cost_for_two  55568 non-null  int64
#  13  price_range           55568 non-null  int64
#  14  currency              55568 non-null  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55568 entries, 0 to 211942
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   res_id                55568 non-null  int64
#  1   name                  55568 non-null  object
#  2   establishment         55568 non-null  object
#  3   address               55568 non-null  object
#  4   city                  55568 non-null  object
#  5   city_id               55568 non-null  int64
#  6   locality              55568 non-null  object
#  7   latitude              55568 non-null  float64
#  8   longitude             55568 non-null  float64
#  9   locality_verbose      55568 non-null  object
#  10  cuisines              55568 non-null  object
#  11  timings               55568 non-null  object
#  12  average_cost_for_two  55568 non-null  int64
#  13  price_range           55568 non-null  int64
#  14  currency              55568 non-null  object
# ...

# %% [markdown]
# #  **EXPLORATORY DATA ANALYSIS(EDA)**

# %%
top_brands = df["name"].value_counts().head(10)

top_brands = df["name"].value_counts().head(10)

# Plot the top 10 brands with the highest number of outlets
plt.figure(figsize=(12, 6))
sns.barplot(x=top_brands.values, y=top_brands.index, palette=("coolwarm"))
plt.xlabel("Number of Outlets")
plt.ylabel("Restaurant Brand")
plt.title("Top 10 Restaurant Brands with the Most Outlets")
plt.show()
# Out:
# <ipython-input-31-115cfbffe9b8>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_brands.values, y=top_brands.index, palette=("coolwarm"))

# %%
# @title TOP 10 CITIES WITH MOST RESTAURANT
# Get top 10 cities
top_cities = df["city"].value_counts().head(10)

# Plot the top 10 cities with the most restaurants
plt.figure(figsize=(12, 6))
sns.barplot(x=top_cities.values, y=top_cities.index, palette="coolwarm")
plt.xlabel("Number of Restaurants")
plt.ylabel("City")
plt.title("Top 10 Cities with the Most Restaurants")
plt.show()

top_cities
# Out:
# <ipython-input-33-1cecdb8b2871>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cities.values, y=top_cities.index, palette="coolwarm")
# city
# Bangalore    2247
# Mumbai       2022
# Pune         1843
# Chennai      1827
# New Delhi    1704
# Jaipur       1395
# Kolkata      1361
# Ahmedabad    1247
# Goa          1150
# Lucknow      1135
# Name: count, dtype: int64

# %%
# @title most popular cuisine in india {"display-mode":"both"}
from collections import Counter

# Split multiple cuisines and count occurrences
cuisine_list = df['cuisines'].dropna().str.split(', ').sum()
cuisine_counts = Counter(cuisine_list)

# Convert to DataFrame and plot
cuisine_df = pd.DataFrame(cuisine_counts.items(), columns=['Cuisine', 'Count'])
cuisine_df = cuisine_df.sort_values(by='Count', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=cuisine_df['Count'], y=cuisine_df['Cuisine'], palette="viridis")
plt.xlabel("Number of Restaurants")
plt.ylabel("Cuisine")
plt.title("Top 10 Most Popular Cuisines in India")
plt.show()
# Out:
# <ipython-input-93-de92ee5501be>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cuisine_df['Count'], y=cuisine_df['Cuisine'], palette="viridis")

# %%
# @title price range vs ratings {"display-mode":"both"}
plt.figure(figsize=(10, 6))
sns.boxplot(x="price_range", y="aggregate_rating", data=df, palette="Set2")
plt.xlabel("Price Range")
plt.ylabel("Aggregate Rating")
plt.title("Price Range vs. Ratings")
plt.show()
# Out:
# <ipython-input-94-50d5073e93ba>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="price_range", y="aggregate_rating", data=df, palette="Set2")

# %%
# @title distribution of ratings {"display-mode":"both"}
plt.figure(figsize=(10, 6))
sns.histplot(df['aggregate_rating'], bins=20, kde=True, color='red')
plt.xlabel("Ratings")
plt.ylabel("Count")
plt.title("Distribution of Restaurant Ratings")
plt.show()

# %%
# @title delivery vs dining in trends {"display-mode":"both"}
plt.figure(figsize=(8, 4))
delivery_counts = df['delivery'].value_counts()
labels = delivery_counts.index.tolist()
label_maping ={-1:'No Delivery',0: 'unknown',1: 'Delivery'}
labels =[label_maping.get(label,label) for label in labels]
plt.pie(delivery_counts, labels=labels, autopct='%1.1f%%', colors=['red','yellow','green'])
plt.title("Percentage of Restaurants Offering Delivery")
plt.show()

# %%
# @title top rated restaurants in india
top_rated_restaurants = df[df["aggregate_rating"] == 4.9][["name", "city", "cuisines", "votes"]]

# Display the top 10 highest-rated restaurants in India
top_rated_restaurants.head(10)
# Out:
#                                     name        city  \
# 4            The Salt Cafe Kitchen & Bar        Agra
# 2688                          Buttercupp   Ahmedabad
# 2705                      Yanki Sizzlers   Ahmedabad
# 2718                      Yanki Sizzlers   Ahmedabad
# 2754   TG’s - The Oriental Grill - Hyatt   Ahmedabad
# 13269                     Hotel Abdullah    Amravati
# 15114                   La Roma Pizzeria    Amritsar
# 17466                         Green Leaf  Aurangabad
# 19630                         Biergarten   Bangalore
# 19636        Byg Brewski Brewing Company   Bangalore
#
#                                                 cuisines  votes
# 4                     North Indian, Continental, Italian    470
# 2688                                    Desserts, Bakery   1455
# 2705                       Continental, Italian, Chinese   3610
# 2718              Continental, Italian, Chinese, Mexican   1009
# ...

# %%
# @title votes vs. ratings {"display-mode":"both"}
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df["votes"], y=df["aggregate_rating"], alpha=0.5, color="blue")

plt.xlabel("Number of Votes")
plt.ylabel("Aggregate Rating")
plt.title("Votes vs. Ratings")
plt.xlim(0, df["votes"].quantile(0.95))  # Limit extreme values for better visualization
plt.show()

# %%
# @title geographical distribution of restaurants in india {"display-mode":"both"}
plt.figure(figsize=(8, 8))
sns.scatterplot(x=df["longitude"], y=df["latitude"], alpha=0.5, color="red")

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Geographical Distribution of Restaurants in India")
plt.show()

# %%
# @title distribution of votes for restaurants {"display-mode":"both"}
plt.figure(figsize=(10, 6))
sns.kdeplot(df["votes"], shade=True, color="green")

plt.xlabel("Number of Votes")
plt.ylabel("Density")
plt.title("Distribution of Votes for Restaurants")
plt.xlim(0, df["votes"].quantile(0.95))  # Limit extreme values for better visualization
plt.show()
# Out:
# <ipython-input-103-51ce3500f4b2>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["votes"], shade=True, color="green")

# %%
# @title density of price range {"display-mode":"both"}
plt.figure(figsize=(10, 6))
sns.kdeplot(df["price_range"], shade=True, color="red")

plt.xlabel("Price Range")
plt.ylabel("Density")
plt.title("Density of Price Ranges")
plt.show()
# Out:
# <ipython-input-104-41cfb09e8e0a>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["price_range"], shade=True, color="red")

# %%
# @title average ratings by price range
# Group by price range
price_rating = df.groupby("price_range")["aggregate_rating"].mean().sort_values()

# Plot bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=price_rating.index, y=price_rating.values, palette="Blues_r")

plt.xlabel("Price Range")
plt.ylabel("Average Rating")
plt.title("Average Ratings by Price Range")
plt.show()
# Out:
# <ipython-input-105-ab6c61ecbd33>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=price_rating.index, y=price_rating.values, palette="Blues_r")

# %%
# @title number of restaurants by price range
plt.figure(figsize=(10, 6))
sns.countplot(x=df["price_range"], palette="magma")

plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")
plt.title("Number of Restaurants by Price Range")
plt.show()
# Out:
# <ipython-input-106-3e8e3e9d7154>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["price_range"], palette="magma")

# %% [markdown]
# # **conclusion**
# 1️⃣ Major Cities Dominate the Restaurant Industry 🏙️
#
# .The highest number of restaurants are located in major metro cities like Delhi, Mumbai, Bangalore, and Hyderabad.
#
# .This indicates that urban areas have a high demand for dining options, making them prime locations for new restaurants.
#
# 2️⃣ Indian Cuisine is the Most Popular, But Other Cuisines Are Growing 🍽️
#
# .The most frequently served cuisines include North Indian, Chinese, South Indian, and Fast Food.
#
# .International cuisines like Italian, Continental, and Mexican are also gaining popularity, indicating a diverse food culture in India.
#
# 3️⃣ Higher Price Doesn’t Always Mean Higher Ratings 💰⭐
#
# .The analysis showed that restaurants in higher price ranges do not always have the highest ratings.
#
# .Mid-range restaurants (Price Range 2 & 3) tend to receive better ratings compared to the most expensive ones.
#
# .This suggests that good food and service matter more than high prices for customer satisfaction.
#
# 4️⃣ Most Restaurants Have Moderate to High Ratings 📊
#
# .The majority of restaurants have ratings between 3.5 to 4.5, showing that customers generally have a good dining experience.
#
# .Very few restaurants received low ratings (<2.5), indicating that low-quality places struggle to survive in the competitive market.
#
# 5️⃣ Online Food Delivery is a Growing Trend 🚚
#
# .A large percentage of restaurants now offer delivery services, reflecting the rise in online food ordering via Zomato, Swiggy, etc.
#
# .This trend suggests that cloud kitchens and delivery-focused restaurants are becoming more profitable.
#
# 6️⃣ Bangalore Has the Most 5-Star Restaurants 🌟
#
# .When analyzing top-rated restaurants (5-star ratings), Bangalore had the most highly-rated places.
#
# .This shows a strong preference for high-quality dining in tech hubs and metro cities.
